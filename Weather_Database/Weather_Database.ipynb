# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests

# %%
# Create a set of 2,000 random latitudes and longitudes.
latitudes = np.random.uniform(low = -90, high = 90, size = 2000)
longitudes = np.random.uniform(low = -180, high = 180, size = 2000)
latitudes_longitudes = zip(latitudes, longitudes)

# Create a list to store latitudes and longitudes.
coordinates = list(latitudes_longitudes)

# %%
# Create an empty list to store the cities.
cities = []

# Get the nearest city for each latitudes/longitudes.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # Add city if unique in the cities list.
    if city not in cities:
        cities. append(city)
# len(cities)

# %%
# Import API key.
from key import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
                    

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | tazovskiy
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | qobustan
# Processing Record 16 of Set 1 | belmonte
# Processing Record 17 of Set 1 | roebourne
# Processing Record 18 of Set 1 | rorvik
# Processing Record 19 of Set 1 | scicli
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | egvekinot
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | los llanos de aridane
# Processing Record 25 of Set 1 | morgan city
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | labuhan
# Processing Record 30 of Set 1 | dalby
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | bida
# Processing Record 33 of Set 1 | comodoro rivadavia
# Processing Record 34 of Set 1 | nautla
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | okha
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | nelson bay
# Processing Record 41 of Set 1 | luderitz
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | douglas
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | sumbe
# Processing Record 3 of Set 2 | noshiro
# Processing Record 4 of Set 2 | benguela
# Processing Record 5 of Set 2 | inirida
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | sao gabriel da cachoeira
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | provideniya
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | iberia
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | etchojoa
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | ixcatepec
# Processing Record 21 of Set 2 | itarema
# Processing Record 22 of Set 2 | halifax
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | villamontes
# Processing Record 25 of Set 2 | lorengau
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | hlotse
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | sola
# Processing Record 30 of Set 2 | rocky mountain house
# Processing Record 31 of Set 2 | te anau
# Processing Record 32 of Set 2 | filotion
# Processing Record 33 of Set 2 | birjand
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | porto novo
# Processing Record 36 of Set 2 | lermontovka
# Processing Record 37 of Set 2 | kirakira
# Processing Record 38 of Set 2 | sabha
# Processing Record 39 of Set 2 | grand-santi
# Processing Record 40 of Set 2 | bacolod
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | atar
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 | pisco
# Processing Record 49 of Set 2 | karrapur
# Processing Record 50 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | xiongshi
# City not found. Skipping...
# Processing Record 6 of Set 3 | fortuna
# Processing Record 7 of Set 3 | honningsvag
# Processing Record 8 of Set 3 | kapaa
# Processing Record 9 of Set 3 | aklavik
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | pulandian
# Processing Record 13 of Set 3 | raub
# Processing Record 14 of Set 3 | avrille
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | kapit
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | lagoa
# Processing Record 19 of Set 3 | grand gaube
# Processing Record 20 of Set 3 | angoche
# Processing Record 21 of Set 3 | rocha
# Processing Record 22 of Set 3 | dikson
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | mersing
# Processing Record 25 of Set 3 | baraboo
# Processing Record 26 of Set 3 | jaciara
# Processing Record 27 of Set 3 | takoradi
# Processing Record 28 of Set 3 | ewo
# Processing Record 29 of Set 3 | santa fe
# Processing Record 30 of Set 3 | lavrentiya
# Processing Record 31 of Set 3 | sao miguel
# Processing Record 32 of Set 3 | solvychegodsk
# Processing Record 33 of Set 3 | madang
# Processing Record 34 of Set 3 | catuday
# Processing Record 35 of Set 3 | olafsvik
# Processing Record 36 of Set 3 | alta floresta
# Processing Record 37 of Set 3 | kadaya
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | predivinsk
# Processing Record 40 of Set 3 | bhawanigarh
# Processing Record 41 of Set 3 | fomboni
# Processing Record 42 of Set 3 | ocos
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | pacific grove
# Processing Record 45 of Set 3 | cabadiangan
# Processing Record 46 of Set 3 | moree
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | cayenne
# Processing Record 49 of Set 3 | nara
# Processing Record 50 of Set 3 | taldan
# Processing Record 1 of Set 4 | nikolskoye
# Processing Record 2 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 3 of Set 4 | gardan diwal
# City not found. Skipping...
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | yulara
# Processing Record 6 of Set 4 | san cristobal
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | storrs
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | stabat
# Processing Record 12 of Set 4 | alice springs
# Processing Record 13 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 14 of Set 4 | mehamn
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | sambava
# Processing Record 17 of Set 4 | dwarka
# Processing Record 18 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 19 of Set 4 | itapirapua
# Processing Record 20 of Set 4 | copiapo
# Processing Record 21 of Set 4 | buraydah
# Processing Record 22 of Set 4 | pundaguitan
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | kaduna
# Processing Record 25 of Set 4 | panzhihua
# Processing Record 26 of Set 4 | havelian
# Processing Record 27 of Set 4 | half moon bay
# Processing Record 28 of Set 4 | coahuayana
# Processing Record 29 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 4 | tevaitoa
# Processing Record 31 of Set 4 | naze
# Processing Record 32 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 4 | mananjary
# Processing Record 34 of Set 4 | luocheng
# Processing Record 35 of Set 4 | ouallam
# Processing Record 36 of Set 4 | svetlyy
# Processing Record 37 of Set 4 | aykhal
# Processing Record 38 of Set 4 | plainview
# Processing Record 39 of Set 4 | college
# Processing Record 40 of Set 4 | boende
# Processing Record 41 of Set 4 | honggang
# Processing Record 42 of Set 4 | mapiri
# Processing Record 43 of Set 4 | gorahun
# Processing Record 44 of Set 4 | penzance
# Processing Record 45 of Set 4 | pinega
# Processing Record 46 of Set 4 | mount pleasant
# Processing Record 47 of Set 4 | zambezi
# Processing Record 48 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 4 | verkhoyansk
# Processing Record 50 of Set 4 | hrusovany nad jevisovkou
# Processing Record 1 of Set 5 | soledad
# Processing Record 2 of Set 5 | bambous virieux
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | doctor juan manuel frutos
# Processing Record 5 of Set 5 | nouadhibou
# Processing Record 6 of Set 5 | seydi
# Processing Record 7 of Set 5 | mangan
# Processing Record 8 of Set 5 | iqaluit
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | liverpool
# Processing Record 11 of Set 5 | vega de alatorre
# Processing Record 12 of Set 5 | srandakan
# Processing Record 13 of Set 5 | touros
# Processing Record 14 of Set 5 | gladstone
# Processing Record 15 of Set 5 | charters towers
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | gao
# Processing Record 18 of Set 5 | flinders
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | fairbanks
# Processing Record 21 of Set 5 | ostrovnoy
# Processing Record 22 of Set 5 | nome
# Processing Record 23 of Set 5 | mana
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | hervey bay
# Processing Record 26 of Set 5 | ceres
# Processing Record 27 of Set 5 | giyani
# Processing Record 28 of Set 5 | banjar
# Processing Record 29 of Set 5 | seoul
# Processing Record 30 of Set 5 | atambua
# Processing Record 31 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | namibe
# Processing Record 34 of Set 5 | pandan
# Processing Record 35 of Set 5 | mildura
# Processing Record 36 of Set 5 | bundaberg
# Processing Record 37 of Set 5 | saldanha
# Processing Record 38 of Set 5 | dunedin
# Processing Record 39 of Set 5 | yumen
# Processing Record 40 of Set 5 | sefophe
# Processing Record 41 of Set 5 | nishihara
# Processing Record 42 of Set 5 | sinnai
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | cascais
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 48 of Set 5 | mpongwe
# Processing Record 49 of Set 5 | vardo
# Processing Record 50 of Set 5 | port-gentil
# Processing Record 1 of Set 6 | qaqortoq
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | udachnyy
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | rabo de peixe
# Processing Record 6 of Set 6 | amahai
# Processing Record 7 of Set 6 | jurm
# Processing Record 8 of Set 6 | pangnirtung
# Processing Record 9 of Set 6 | karatau
# Processing Record 10 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | gobabis
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of Set 6 | vanimo
# Processing Record 17 of Set 6 | cap malheureux
# Processing Record 18 of Set 6 | sangar
# Processing Record 19 of Set 6 | tonj
# Processing Record 20 of Set 6 | gonbad-e qabus
# Processing Record 21 of Set 6 | talnakh
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | quatre cocos
# Processing Record 24 of Set 6 | upernavik
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | bonavista
# Processing Record 27 of Set 6 | nushki
# Processing Record 28 of Set 6 | puerto escondido
# Processing Record 29 of Set 6 | roald
# Processing Record 30 of Set 6 | pimentel
# Processing Record 31 of Set 6 | axim
# Processing Record 32 of Set 6 | kloulklubed
# Processing Record 33 of Set 6 | eyl
# Processing Record 34 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 6 | meulaboh
# Processing Record 36 of Set 6 | saint george
# Processing Record 37 of Set 6 | ternovka
# Processing Record 38 of Set 6 | thompson
# Processing Record 39 of Set 6 | dawei
# Processing Record 40 of Set 6 | santa isabel
# Processing Record 41 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 6 | beipiao
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | cabo rojo
# Processing Record 45 of Set 6 | saryozek
# Processing Record 46 of Set 6 | tecoanapa
# Processing Record 47 of Set 6 | salta
# Processing Record 48 of Set 6 | lasa
# Processing Record 49 of Set 6 | grindavik
# Processing Record 50 of Set 6 | leningradskiy
# Processing Record 1 of Set 7 | shelburne
# Processing Record 2 of Set 7 | makaryev
# Processing Record 3 of Set 7 | hofn
# Processing Record 4 of Set 7 | granada
# Processing Record 5 of Set 7 | sao jose do belmonte
# Processing Record 6 of Set 7 | saint-joseph
# Processing Record 7 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 7 | araouane
# Processing Record 9 of Set 7 | maunabo
# Processing Record 10 of Set 7 | amga
# Processing Record 11 of Set 7 | durant
# Processing Record 12 of Set 7 | diego de almagro
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | kindu
# Processing Record 15 of Set 7 | darhan
# Processing Record 16 of Set 7 | rafai
# Processing Record 17 of Set 7 | san buenaventura
# Processing Record 18 of Set 7 | laguna
# Processing Record 19 of Set 7 | komsomolskiy
# Processing Record 20 of Set 7 | havre-saint-pierre
# Processing Record 21 of Set 7 | caravelas
# Processing Record 22 of Set 7 | sebastian
# Processing Record 23 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 7 | bayan
# Processing Record 25 of Set 7 | portland
# Processing Record 26 of Set 7 | milkovo
# Processing Record 27 of Set 7 | marzuq
# Processing Record 28 of Set 7 | shimoda
# Processing Record 29 of Set 7 | marawi
# Processing Record 30 of Set 7 | rybachiy
# Processing Record 31 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 7 | ambilobe
# Processing Record 33 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 7 | blagoyevo
# Processing Record 35 of Set 7 | srikakulam
# Processing Record 36 of Set 7 | palamas
# Processing Record 37 of Set 7 | juneau
# Processing Record 38 of Set 7 | two hills
# Processing Record 39 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 7 | linjiang
# Processing Record 41 of Set 7 | revelstoke
# Processing Record 42 of Set 7 | waipawa
# Processing Record 43 of Set 7 | port-cartier
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | yerbogachen
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | kankon
# Processing Record 48 of Set 7 | auki
# Processing Record 49 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 7 | bessonovka
# Processing Record 1 of Set 8 | gazanjyk
# Processing Record 2 of Set 8 | hamilton
# Processing Record 3 of Set 8 | calama
# Processing Record 4 of Set 8 | shubarshi
# Processing Record 5 of Set 8 | galanta
# Processing Record 6 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 8 | luanshya
# Processing Record 8 of Set 8 | aleksin
# Processing Record 9 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 10 of Set 8 | fountain hills
# Processing Record 11 of Set 8 | omboue
# Processing Record 12 of Set 8 | tigil
# Processing Record 13 of Set 8 | tessalit
# Processing Record 14 of Set 8 | raudeberg
# Processing Record 15 of Set 8 | coquimbo
# Processing Record 16 of Set 8 | kiunga
# Processing Record 17 of Set 8 | sao francisco do sul
# Processing Record 18 of Set 8 | nsanje
# Processing Record 19 of Set 8 | tilichiki
# Processing Record 20 of Set 8 | pontian kecil
# Processing Record 21 of Set 8 | taoudenni
# Processing Record 22 of Set 8 | troyes
# Processing Record 23 of Set 8 | marabba
# Processing Record 24 of Set 8 | coihaique
# Processing Record 25 of Set 8 | muros
# Processing Record 26 of Set 8 | canutama
# Processing Record 27 of Set 8 | bella union
# Processing Record 28 of Set 8 | bemidji
# Processing Record 29 of Set 8 | inongo
# Processing Record 30 of Set 8 | luanda
# Processing Record 31 of Set 8 | amapa
# Processing Record 32 of Set 8 | tabory
# Processing Record 33 of Set 8 | junction city
# Processing Record 34 of Set 8 | necochea
# Processing Record 35 of Set 8 | dongsheng
# Processing Record 36 of Set 8 | busayra
# Processing Record 37 of Set 8 | cotonou
# Processing Record 38 of Set 8 | cockburn town
# Processing Record 39 of Set 8 | fuerte olimpo
# Processing Record 40 of Set 8 | samarai
# Processing Record 41 of Set 8 | husavik
# Processing Record 42 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 8 | jumla
# Processing Record 45 of Set 8 | hobyo
# Processing Record 46 of Set 8 | aranos
# Processing Record 47 of Set 8 | anloga
# Processing Record 48 of Set 8 | richards bay
# Processing Record 49 of Set 8 | sorong
# Processing Record 50 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 9 | salvacion
# Processing Record 2 of Set 9 | eureka
# Processing Record 3 of Set 9 | diu
# Processing Record 4 of Set 9 | kebemer
# City not found. Skipping...
# Processing Record 5 of Set 9 | batagay
# Processing Record 6 of Set 9 | westport
# Processing Record 7 of Set 9 | armidale
# Processing Record 8 of Set 9 | igrim
# Processing Record 9 of Set 9 | erenhot
# Processing Record 10 of Set 9 | hirtshals
# Processing Record 11 of Set 9 | qandala
# Processing Record 12 of Set 9 | vila franca do campo
# Processing Record 13 of Set 9 | maymyo
# Processing Record 14 of Set 9 | kapuskasing
# Processing Record 15 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 9 | taltal
# Processing Record 17 of Set 9 | umm lajj
# Processing Record 18 of Set 9 | broken hill
# Processing Record 19 of Set 9 | swinford
# Processing Record 20 of Set 9 | owo
# Processing Record 21 of Set 9 | maceio
# Processing Record 22 of Set 9 | tomatlan
# Processing Record 23 of Set 9 | saint-augustin
# Processing Record 24 of Set 9 | fort nelson
# Processing Record 25 of Set 9 | souillac
# Processing Record 26 of Set 9 | ulu-telyak
# Processing Record 27 of Set 9 | praia da vitoria
# Processing Record 28 of Set 9 | hanzhong
# Processing Record 29 of Set 9 | portree
# Processing Record 30 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 9 | sabang
# Processing Record 32 of Set 9 | pahrump
# Processing Record 33 of Set 9 | kourou
# Processing Record 34 of Set 9 | cherskiy
# Processing Record 35 of Set 9 | ivanteyevka
# Processing Record 36 of Set 9 | almaznyy
# Processing Record 37 of Set 9 | klyuchi
# Processing Record 38 of Set 9 | berlevag
# Processing Record 39 of Set 9 | camacha
# Processing Record 40 of Set 9 | codrington
# Processing Record 41 of Set 9 | zaragoza
# Processing Record 42 of Set 9 | bethanien
# Processing Record 43 of Set 9 | imeni poliny osipenko
# Processing Record 44 of Set 9 | staraya russa
# Processing Record 45 of Set 9 | rawson
# Processing Record 46 of Set 9 | kyshtovka
# Processing Record 47 of Set 9 | eaton socon
# Processing Record 48 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 9 | wismar
# Processing Record 50 of Set 9 | kipushi
# Processing Record 1 of Set 10 | belaya gora
# Processing Record 2 of Set 10 | kieta
# Processing Record 3 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 10 | damaturu
# Processing Record 5 of Set 10 | mweka
# Processing Record 6 of Set 10 | pokaran
# Processing Record 7 of Set 10 | monrovia
# Processing Record 8 of Set 10 | klaksvik
# Processing Record 9 of Set 10 | timbiqui
# Processing Record 10 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 10 | issia
# Processing Record 12 of Set 10 | kayes
# Processing Record 13 of Set 10 | anori
# Processing Record 14 of Set 10 | palu
# Processing Record 15 of Set 10 | pachino
# Processing Record 16 of Set 10 | beringovskiy
# Processing Record 17 of Set 10 | bataipora
# Processing Record 18 of Set 10 | totskoye
# Processing Record 19 of Set 10 | bilma
# Processing Record 20 of Set 10 | tukrah
# Processing Record 21 of Set 10 | san joaquin
# Processing Record 22 of Set 10 | cedar city
# Processing Record 23 of Set 10 | catende
# Processing Record 24 of Set 10 | taywarah
# Processing Record 25 of Set 10 | registro
# Processing Record 26 of Set 10 | togur
# Processing Record 27 of Set 10 | chuguyevka
# Processing Record 28 of Set 10 | kon tum
# Processing Record 29 of Set 10 | mnogovershinnyy
# Processing Record 30 of Set 10 | constitucion
# Processing Record 31 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 10 | kuzedeyevo
# Processing Record 33 of Set 10 | gemena
# Processing Record 34 of Set 10 | stuttgart
# Processing Record 35 of Set 10 | novo aripuana
# Processing Record 36 of Set 10 | mormugao
# Processing Record 37 of Set 10 | nogales
# Processing Record 38 of Set 10 | qarqin
# Processing Record 39 of Set 10 | high rock
# Processing Record 40 of Set 10 | strezhevoy
# Processing Record 41 of Set 10 | masvingo
# Processing Record 42 of Set 10 | noamundi
# Processing Record 43 of Set 10 | huarmey
# Processing Record 44 of Set 10 | taitung
# Processing Record 45 of Set 10 | swan hill
# Processing Record 46 of Set 10 | zephyrhills
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | hami
# Processing Record 49 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 10 | rosarito
# Processing Record 1 of Set 11 | bireun
# Processing Record 2 of Set 11 | pangody
# Processing Record 3 of Set 11 | alofi
# Processing Record 4 of Set 11 | faya
# Processing Record 5 of Set 11 | kahului
# Processing Record 6 of Set 11 | warrnambool
# Processing Record 7 of Set 11 | oga
# Processing Record 8 of Set 11 | saint anthony
# Processing Record 9 of Set 11 | cerro largo
# Processing Record 10 of Set 11 | awjilah
# Processing Record 11 of Set 11 | yantzaza
# Processing Record 12 of Set 11 | codajas
# Processing Record 13 of Set 11 | antofagasta
# Processing Record 14 of Set 11 | cubuk
# Processing Record 15 of Set 11 | tura
# Processing Record 16 of Set 11 | reinosa
# Processing Record 17 of Set 11 | parkes
# Processing Record 18 of Set 11 | cairns
# Processing Record 19 of Set 11 | ahuimanu
# Processing Record 20 of Set 11 | dzilam gonzalez
# Processing Record 21 of Set 11 | celestun
# Processing Record 22 of Set 11 | jiangkou
# Processing Record 23 of Set 11 | matara
# Processing Record 24 of Set 11 | koryazhma
# Processing Record 25 of Set 11 | sistranda
# Processing Record 26 of Set 11 | yangambi
# Processing Record 27 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 11 | faanui
# Processing Record 29 of Set 11 | zemio
# Processing Record 30 of Set 11 | verkhnevilyuysk
# Processing Record 31 of Set 11 | tianpeng
# Processing Record 32 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 11 | dukat
# Processing Record 34 of Set 11 | koidu
# Processing Record 35 of Set 11 | doka
# Processing Record 36 of Set 11 | sibu
# Processing Record 37 of Set 11 | zhigansk
# Processing Record 38 of Set 11 | isoka
# Processing Record 39 of Set 11 | merauke
# Processing Record 40 of Set 11 | pemangkat
# Processing Record 41 of Set 11 | katrineholm
# Processing Record 42 of Set 11 | sovetskiy
# Processing Record 43 of Set 11 | ustynivka
# Processing Record 44 of Set 11 | adrar
# Processing Record 45 of Set 11 | manggar
# Processing Record 46 of Set 11 | haicheng
# Processing Record 47 of Set 11 | portobelo
# Processing Record 48 of Set 11 | kailua
# Processing Record 49 of Set 11 | toba
# Processing Record 50 of Set 11 | palafrugell
# Processing Record 1 of Set 12 | ambatofinandrahana
# Processing Record 2 of Set 12 | katherine
# Processing Record 3 of Set 12 | flin flon
# Processing Record 4 of Set 12 | iranshahr
# Processing Record 5 of Set 12 | zaraza
# Processing Record 6 of Set 12 | namwala
# Processing Record 7 of Set 12 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 8 of Set 12 | arkhangelsk
# Processing Record 9 of Set 12 | boddam
# Processing Record 10 of Set 12 | bageshwar
# Processing Record 11 of Set 12 | ozernovskiy
# Processing Record 12 of Set 12 | torbay
# Processing Record 13 of Set 12 | marshfield
# Processing Record 14 of Set 12 | isangel
# Processing Record 15 of Set 12 | mayo
# Processing Record 16 of Set 12 | nokaneng
# Processing Record 17 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 12 | vila velha
# Processing Record 19 of Set 12 | avera
# Processing Record 20 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 12 | ordu
# Processing Record 22 of Set 12 | bathsheba
# Processing Record 23 of Set 12 | uvat
# Processing Record 24 of Set 12 | arlit
# Processing Record 25 of Set 12 | caucaia
# Processing Record 26 of Set 12 | zaysan
# Processing Record 27 of Set 12 | barra do garcas
# Processing Record 28 of Set 12 | spassk
# Processing Record 29 of Set 12 | port lincoln
# Processing Record 30 of Set 12 | minot
# Processing Record 31 of Set 12 | poronaysk
# Processing Record 32 of Set 12 | kefamenanu
# Processing Record 33 of Set 12 | verkhnetulomskiy
# Processing Record 34 of Set 12 | padang
# Processing Record 35 of Set 12 | la ronge
# Processing Record 36 of Set 12 | payo
# Processing Record 37 of Set 12 | aldana
# Processing Record 38 of Set 12 | conceicao do araguaia
# Processing Record 39 of Set 12 | beloha
# Processing Record 40 of Set 12 | kinston
# Processing Record 41 of Set 12 | caceres
# Processing Record 42 of Set 12 | surt
# Processing Record 43 of Set 12 | rapid valley
# Processing Record 44 of Set 12 | nemuro
# Processing Record 45 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 12 | hrazdan
# Processing Record 47 of Set 12 | mahad
# Processing Record 48 of Set 12 | mount gambier
# Processing Record 49 of Set 12 | deputatskiy
# Processing Record 50 of Set 12 | miraflores
# Processing Record 1 of Set 13 | san cosme y damian
# Processing Record 2 of Set 13 | mirabad
# Processing Record 3 of Set 13 | krasnoselkup
# Processing Record 4 of Set 13 | poya
# Processing Record 5 of Set 13 | jalingo
# Processing Record 6 of Set 13 | san policarpo
# Processing Record 7 of Set 13 | garowe
# Processing Record 8 of Set 13 | gazojak
# Processing Record 9 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 13 | batemans bay
# Processing Record 11 of Set 13 | rudnogorsk
# Processing Record 12 of Set 13 | hay river
# Processing Record 13 of Set 13 | mirnyy
# Processing Record 14 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 15 of Set 13 | stokmarknes
# Processing Record 16 of Set 13 | mosquera
# Processing Record 17 of Set 13 | ugoofaaru
# Processing Record 18 of Set 13 | manitouwadge
# Processing Record 19 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 20 of Set 13 | henties bay
# Processing Record 21 of Set 13 | vrangel
# Processing Record 22 of Set 13 | araxa
# Processing Record 23 of Set 13 | korla
# Processing Record 24 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 13 | tulum
# Processing Record 26 of Set 13 | port macquarie
# Processing Record 27 of Set 13 | beinamar
# Processing Record 28 of Set 13 | corn island
# Processing Record 29 of Set 13 | evensk
# Processing Record 30 of Set 13 | elizabeth city
# Processing Record 31 of Set 13 | pushkino
# Processing Record 32 of Set 13 | kudahuvadhoo
# Processing Record 33 of Set 13 | yatou
# Processing Record 34 of Set 13 | huadian
# Processing Record 35 of Set 13 | loikaw
# Processing Record 36 of Set 13 | waw
# Processing Record 37 of Set 13 | acara
# Processing Record 38 of Set 13 | kovdor
# Processing Record 39 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 40 of Set 13 | jalu
# Processing Record 41 of Set 13 | natal
# Processing Record 42 of Set 13 | feijo
# Processing Record 43 of Set 13 | kurumkan
# Processing Record 44 of Set 13 | gat
# Processing Record 45 of Set 13 | asau
# Processing Record 46 of Set 13 | ambon
# Processing Record 47 of Set 13 | soyaux
# Processing Record 48 of Set 13 | tigzirt
# Processing Record 49 of Set 13 | bonthe
# Processing Record 50 of Set 13 | aktash
# Processing Record 1 of Set 14 | palana
# Processing Record 2 of Set 14 | karratha
# Processing Record 3 of Set 14 | ponta delgada
# Processing Record 4 of Set 14 | ranfurly
# Processing Record 5 of Set 14 | stornoway
# Processing Record 6 of Set 14 | kununurra
# Processing Record 7 of Set 14 | aszod
# Processing Record 8 of Set 14 | albury
# Processing Record 9 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 10 of Set 14 | popondetta
# Processing Record 11 of Set 14 | buchanan
# Processing Record 12 of Set 14 | colon
# Processing Record 13 of Set 14 | aiquile
# Processing Record 14 of Set 14 | balancan
# Processing Record 15 of Set 14 | qujing
# Processing Record 16 of Set 14 | inverell
# Processing Record 17 of Set 14 | matameye
# City not found. Skipping...
# Processing Record 18 of Set 14 | shawnee
# Processing Record 19 of Set 14 | saryg-sep
# Processing Record 20 of Set 14 | novoagansk
# Processing Record 21 of Set 14 | oskemen
# Processing Record 22 of Set 14 | tuatapere
# Processing Record 23 of Set 14 | lazaro cardenas
# Processing Record 24 of Set 14 | lyngseidet
# Processing Record 25 of Set 14 | nouakchott
# Processing Record 26 of Set 14 | sioux lookout
# Processing Record 27 of Set 14 | chernushka
# Processing Record 28 of Set 14 | ingham
# Processing Record 29 of Set 14 | inzhavino
# Processing Record 30 of Set 14 | payakumbuh
# Processing Record 31 of Set 14 | gazni
# City not found. Skipping...
# Processing Record 32 of Set 14 | kaeo
# Processing Record 33 of Set 14 | teguise
# Processing Record 34 of Set 14 | khani
# Processing Record 35 of Set 14 | gumdag
# Processing Record 36 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 37 of Set 14 | kemijarvi
# Processing Record 38 of Set 14 | severomuysk
# Processing Record 39 of Set 14 | progreso
# Processing Record 40 of Set 14 | kouango
# Processing Record 41 of Set 14 | plettenberg bay
# Processing Record 42 of Set 14 | karakol
# Processing Record 43 of Set 14 | samagaltay
# Processing Record 44 of Set 14 | novikovo
# Processing Record 45 of Set 14 | iquitos
# Processing Record 46 of Set 14 | cape canaveral
# Processing Record 47 of Set 14 | vokhtoga
# Processing Record 48 of Set 14 | svetlaya
# Processing Record 49 of Set 14 | luan
# Processing Record 50 of Set 14 | guangyuan
# Processing Record 1 of Set 15 | ipixuna
# Processing Record 2 of Set 15 | bacungan
# Processing Record 3 of Set 15 | esqueda
# Processing Record 4 of Set 15 | puri
# Processing Record 5 of Set 15 | mancio lima
# Processing Record 6 of Set 15 | pyshchug
# Processing Record 7 of Set 15 | broome
# Processing Record 8 of Set 15 | kirovsk
# Processing Record 9 of Set 15 | fukuma
# Processing Record 10 of Set 15 | chatra
# Processing Record 11 of Set 15 | malanje
# Processing Record 12 of Set 15 | son la
# Processing Record 13 of Set 15 | namatanai
# Processing Record 14 of Set 15 | jabinyanah
# Processing Record 15 of Set 15 | ossora
# Processing Record 16 of Set 15 | altamira
# Processing Record 17 of Set 15 | shingu
# Processing Record 18 of Set 15 | bamiantong
# Processing Record 19 of Set 15 | paamiut
# Processing Record 20 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 21 of Set 15 | otjimbingwe
# Processing Record 22 of Set 15 | sayla
# Processing Record 23 of Set 15 | west wendover
# Processing Record 24 of Set 15 | minab
# Processing Record 25 of Set 15 | helong
# Processing Record 26 of Set 15 | sorland
# Processing Record 27 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 28 of Set 15 | newport
# Processing Record 29 of Set 15 | ormara
# Processing Record 30 of Set 15 | acapulco
# Processing Record 31 of Set 15 | bronnoysund
# Processing Record 32 of Set 15 | ondorhaan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     New Norfolk      AU -42.7826  147.0587     66.00        52          75
# 1         Qaanaaq      GL  77.4840  -69.3632     -0.33        75         100
# 2  Port Elizabeth      ZA -33.9180   25.5701     64.40        93           0
# 3       Tazovskiy      RU  67.4667   78.7000    -14.57        88          69
# 4    Punta Arenas      CL -53.1500  -70.9167     55.40        58          99
#
#    Wind Speed Current Description
# 0       10.29       broken clouds
# 1        8.32     overcast clouds
# 2        2.24           clear sky
# 3       12.10       broken clouds
# 4        6.93     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
